# %%
import pandas as pd

# %%
import os

# %%
cwd = os.path.abspath('/Users/shivaniannu/Downloads')

# %%
file_list = os.listdir(cwd)

# %%
file_list
# Out:
# ['Cosign Agreement copy.docx',
#  'IMG_9636.HEIC',
#  'MLFinalPPT.pptx',
#  'MPI_type_indexed.c',
#  '5_Reg3_Tr_S.csv',
#  'mandelbrot_parallel.cpp',
#  'ind rts report.pdf',
#  'coop training.docx',
#  'Mymensingh,Bangladesh 2018-07-01 to 2018-12-31.csv',
#  'predictions.npy',
#  'CSCI 555.docx',
#  'orderedlist.html',
#  'googlechrome.dmg',
#  'mybcast.cpp',
#  'Nonimmigrant Visa - Confirmation Page.pdf',
#  'ch1.pdf',
#  'Milestone 2.docx',
#  'Cancer-Waiting-Times-2020-21-Data-Extract-Provider-Final.xlsx',
#  'Bankers Algorithm.pdf',
#  'BigData Summary.docx',
#  'IMM5825_1-QGZVD52 (2).pdf',
#  'IMM5739_1-M4XD05R (1).pdf',
#  'api_scripts',
#  'Shankar_A_Resume.pdf',
#  'ADV-C77-20201207T183940Z-001.zip',
#  'IMG_9623.JPG',
#  'Part time resume.pdf',
#  'Milestone 2 (1).pdf',
#  'UAEAP18013001456.pdf',
#  'CSCI597-LectureSlidesSet2 - SVM.pptx',
#  'Key dates of the Real Time Systems course (3).docx',
#  'b07d1bdce5b4445fb03551fe092b345b.MOV',
#  'Turbine_Data.csv.zip',
# ...

# %%
df = pd.concat( map(pd.read_csv, ['Mymensingh,Bangladesh 2018-07-01 to 2018-12-31.csv',
'Mymensingh,Bangladesh 2014-01-01 to 2015-12-31.csv',
'Mymensingh,Bangladesh 2016-01-01 to 2016-12-31.csv',
 'Mymensingh,Bangladesh 2017-01-01 to 2018-06-30.csv',
 'Mymensingh,Bangladesh 2018-07-01 to 2018-12-31.csv',
 'Mymensingh,Bangladesh 2019-01-01 to 2019-12-31.csv',
'Mymensingh,Bangladesh 2020-01-01 to 2021-02-28.csv','Mymensingh,Bangladesh 2021-03-01 to 2021-07-31.csv',
'Mymensingh,Bangladesh 2021-08-01 to 2021-12-31.csv','Mymensingh,Bangladesh 2022-01-01 to 2023-10-31.csv',]), ignore_index=True)

# %%
df.to_csv('Mymensingh_noindex.csv', index=False)

# %%
df_new = pd.read_csv('Mymensingh_noindex.csv',index_col='datetime',parse_dates=True)

# %%
df_new.to_csv('Mymensingh.csv')

# %%
df_new.head(5)
# Out:
#                              name  tempmax  tempmin  temp  feelslikemax  \
# datetime
# 2018-07-01  Mymensingh,Bangladesh     30.2     26.2  28.1          39.2
# 2018-07-02  Mymensingh,Bangladesh     31.7     25.9  28.4          42.9
# 2018-07-03  Mymensingh,Bangladesh     29.1     25.7  27.5          36.6
# 2018-07-04  Mymensingh,Bangladesh     30.1     26.2  27.9          39.1
# 2018-07-05  Mymensingh,Bangladesh     32.0     25.9  28.8          42.3
#
#             feelslikemin  feelslike   dew  humidity  precip  ...  solarenergy  \
# datetime                                                     ...
# 2018-07-01          26.2       33.6  26.8      92.7    11.9  ...         11.0
# 2018-07-02          25.9       34.0  26.6      90.3    14.0  ...         20.1
# 2018-07-03          25.7       31.8  26.3      93.1    54.7  ...         11.9
# 2018-07-04          26.2       32.4  26.4      92.0    29.8  ...         14.5
# ...
